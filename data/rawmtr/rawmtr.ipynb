# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA_PATH = Path('../csv_files/raw')
INGREDIENT = 'ingredient.csv'
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_row', None)
# Out:
# /var/folders/3x/nkdkb4j55gl1v6vcq3yq1yjw0000gn/T/ipykernel_3733/2626821563.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # 1. (비선호음식, 원재료명)

# %%
ingredient_df = pd.read_csv(DATA_PATH / INGREDIENT, encoding="utf-8")
print(f'shape: {ingredient_df.shape}')
ingredient_df.head(5)
# Out:
# shape: (64426, 2)
#                                        기존         전처리
# 0                             L-메티오닌0.1mg     L메티오닌mg
# 1                                 정제수48%]         정제수
# 2                                   토마토퓨레       토마토퓨레
# 3   가쓰오부시엑기스 4.9%[가쓰오부시추출액 50.9%(가쓰오부시 5%   가쓰오부시엑기스
# 4                                  햄형후레이크      햄형후레이크

# %%
def search(pname, exclude):
   if exclude:
      filtered = ingredient_df[ingredient_df['기존'].str.contains(exclude)==False]
      filtered = filtered[filtered['기존'].str.contains(pname)==True]
      print(f'{filtered.shape}')
      display(filtered)
      return

   filtered = ingredient_df[ingredient_df['기존'].str.contains(pname)==True]
   print(f'{filtered.shape}')
   display(filtered)

# %%
# 검색 키워드: pname="게"
# 제외할 키워드: exclude="게맛살|게장"
search(pname="게", exclude=None)
# Out:
# (252, 2)
#                                                             기존  \
# 206                               꽃게씨즈닝분말[꽃게농축분말(국산) 35%] 4.5%
# 487                                                    붉은대게엑기스
# 556                                            콘베리게이트[미강유(태국산)
# 575                                              게향0.63%(합성향료)
# 627                                          붉은대게살12.37%(게:국산)
# 827                       가라아게배터-2[베이스믹스-3{프리믹스분말5호<소맥전분(밀:미국산
# 1070                             가라아게배터[가라아게프리믹스{튀김베이스3호(밀:미국산
# 1276                                   가라아게염지제5호{폴리인산나트륨(산도조절제
# 1594                                               게랑드소금(프랑스산)
# 1750                        가라아게배터(3M)[가라아게베이스A{옥수수전분(옥수수:외국산)
# 2196                                             게향0.43%(합성향료)
# 2544                              꽃게엑기스A[1.05%함유(꽃게6.5%상당;국산)]
# 2634                                                  어육추출액(게)
# 2801                                     스파게티[듀럼세몰리나 소맥분100%(밀
# 3295                             향미증진제 *해물함량(생물기준)33.1%(게16.8%
# 3377                                                 게맛살조미후레이크
# 3538                                               소스류1(게:국내산)
# 3816                                                 해물베이스3%(게
# 3819                              크림스파게티베이스D{양송이엑기스분말(양송이:국산)}
# 3852                                         붉은대게농축분말(붉은대게:국산)
# 4423                                                   게 엑기스분말
# 4898                                              꽃게(국내산) 100%
# 4922                                                      게라나올
# 5522                                           스파게티면-밀가루(밀/미국산
# 5850                                *생스파게티면(110gx2개)-밀가루(밀:호주산
# 6032                                         게엑기스-J1.15%(게/국산)
# 6209                                             대게페이스트2.1%(게)
# 6248                                          붉은대게살10.10%(국내산)
# 6300                          N-아세틸글루코시민분말(게)0.011%(글루코사민(NAG)
# 6497                                              붉은대게살9%(국내산)
# 6529                                 스파게티(이탈리아산/듀럼세몰리나소맥분100%)
# 6600                                         게엑기스1.67%{게(국내산)}
# 6630                                                      붉은대게
# 6736                                                     게엑기스)
# 6760                          크림스파게티분말52.7%[가공유크림20%{가공버터(호주산)
# 6960                                                 복합해물농축액(게
# 7059                                      홍게살2.65%[홍게100%(국산)]
# 7224                                                말토게닉아밀라아제)
# 7519                                                         게
# 8042                                        붉은대게다리살10.93%(국내산)
# 8103                                        레드가라게믹스{밀가루(밀:미국산)
# 8358                                                   꽃게탕면건더기
# 8454                                                    꽃게100%
# 8456                                            게향0.79%(합성착향료)
# 9143                                 *스파게티면(150gx3개)-밀가루(밀:미국산
# 9370                                      정제수) 토마토스파게티소스골드:정제수
# 9423                          페스토스파게티야채건더기3.23%{건마늘(중국산)33.5%}
# 9923                                          * 스파게티면(밀:이탈리아산)
# 10371                              붉은대게농축액9.2%{붉은대게59.0%(연근해산)
# 10527                     ?시컴오일(대두) *스파게티치즈분말(2.5gx3개)-알파콘(옥수수
# 10692                                       스파게티소스시즈닝믹스-TS(우유)
# 11557                                                  꽃게풍미베이스
# 11617                       게다리살2.15%(국산) 호두컵샐러드&올리브-그린치커리(국산)
# 11963                                       게엑기스1.39%{게(연근해산)}
# 12310                                                       게)
# 12329                                                (꽃게6.2%상당
# 12446                                       게엑기스1.04%{게(연근해산)}
# 12467                                                     꽃게짬뽕
# 12558                                                       멍게
# 12566                                                   게농축액분말
# 13375                                                   굴소스(게)
# 13451                                           게향0.71%(합성착향료)
# 13972       조개관자엑기스{조개관자추출액[게아지살(중국산)]참치뼈엑기스[참치뼈추출액(참치뼈/원양산)]}
# 14314                          (미트볼로냐) *스파게티면:듀럼휘트세몰리나(밀-이탈리아산
# 14833                                        게향(합성착향료/대두)0.65%
# 14861                                                 게라닐아세테이트
# 14893                                                   냉동게(게)
# 14922                                                 키토후레쉬(게)
# 15024                                                   게엑기스분말
# 15076                                      스파게티소스시즈닝믹스-TSA(정백당
# 15156                      가라아게배터믹스DS[가라아게베이스{바삭한혼합분말(옥수수:수입산)
# 15190                                                    꽃게농축액
# 16029                                                꽃게짬뽕해물건더기
# 16212                                                      게맛살
# 16922                                               말토게닉아밀라아제}
# 17126                               조개관자액기스[조개관자추출액{게아지살(중국산)}
# 17325                                                 갑각류추출물(게
# 17351                                                   게엑기스분말
# 17453                                           후추가루·해물함량:해물(게
# 17840                                          붉은대게살11.68%(국산)
# 17884                                                  가라아게믹스므
# 17957                                         꽃게풍미유[냉동꽃게(중국산)]
# 18057                    순살치킨배터믹스[가라아게베이스H<전분베이스믹스{옥수수전분(외국산)}
# 18097                                                  붉은대게농축액
# 18131                                                 스파게티소스분말
# 18458                                               갑각류분해추추물(게
# 18518                             파스타면:스파게티[듀럼밀 세몰리나(밀:이탈리아산)]
# 18792                                                     게농축액
# 19268                                         붉은대게살12.25%(국내산)
# 19471                                                 키토후레쉬(게)
# 20270                                                  게)0.01%
# 20338                                                        게
# 20735                                         꽃게농축액0.5%(꽃게:국산)
# 20971                                                   게0.03%
# 21025                                     붉은대게자숙액40.6%(연근해산)}]
# 21029                                               [멍게(국산)70%
# 21278                                      칠리토마토스파게티소스(토마토페이스트
# 21863                                           어육추출액(게/향미증진제)
# 21906                                                 크랩엑기스(게)
# 22623                                     게란후레이크-1[전란분(계란:덴마크)
# 23444                                             스파게티용믹스4%(밀)
# 23539                                        튀긴꽃게오일{꽃게(중국산)}]>
# 23568                           치자황색소-300 *스파게티소스(160gx3개)-정제수
# 23620                                             게맛살[연육(외국산)]
# 23812                                      게엑기스-P2.15%{게(국내산)}
# 23830                                         게랑드천일염0.8%(프랑스산)
# 23929                                                  홍게엑기스분말
# 24188                                         게엑기스2.0%{게(국내산)}
# 24302                                          붉은대게살(국내산)13.8%
# 24367                                                     홍게맛살
# 24418                                                    꽃게엑기스
# 24461                                                    치킨엑게스
# 24648                                     게엑기스-디1.04%{게(연근해산)}
# 24740                                                    게 엑기스
# 25242                                                    꽃게추출물
# 25362                                             게맛살[연육(수입산)]
# 25751                                              유산균발효분말S(게)
# 26542                                         가라아게염지제(KJ)옥수수전분
# 26799                                                     게농축액
# 27146                                                  게엑기스(게)
# 27385                                                합성착향료(게향)
# 27393                                          마르게리타다이스토마토(토마토
# 27620                                                게향(합성착향료)
# 27777                  게엑기스(게)}●특정성분함량및원산지:스프류중새우8.6%(중국산80.2%
# 27834                                                  홍게엑기스분말
# 28246                                           게랑드천일염1%(프랑스산)
# 28628                               구연산 ●해물함량(생물기준)35%(게 16.8%
# 28659                                                    게(국산)
# 28823                            꽃게탕액상스프<탕면맛베이스{꽃게엑기스(꽃게:국내산)}
# 29573                                      스파게티18.06%(이탈리아산/밀)
# 29767                                          칠리토마토스파게티소스[정제수
# 29861                                            게향0.45%(합성향료)
# 30330                                                 복합조미식품(게
# 30391                                                       게}
# 30491                                              쓰리인원내츄럴믹스게향
# 30852                                                      게))
# 31799                                          붉은대게살10.10%(국산)
# 31856                                                 합성향료(게향)
# 32465                             트레하) *특정성분:스프 중 홍게 6.9%(생물기준
# 32703                                          키토산 0.02%(게:국산)
# 33287                                                     대게내장
# 33524                                                 조미게엑기스분말
# 34411                                          붉은대게살3.34%(국내산)
# 34771                 정제염 (크림베이컨 스파게티) *스파게티면:듀럼휘트세몰리나(밀-이탈리아산
# 34913                            게추출농축액1호[게엑기스베이스{게베이스(게/중국산)}
# 34927                            게맛살17.14%(어묵/연육(수입산)소맥전분(밀/호주
# 35311                                                게엑기스엔엠(게)
# 35659                                       게추출농축액1호1%(고형분46%)
# 35738                                         게엑기스2.1%{게(국내산)}
# 36334                                                   키토산(게)
# 36861                                              가라아게염지제(대두)
# 37302                                                개농축액분말(게)
# 37890                                          붉은대게살4.37%(국내산)
# 38073                                        게엑기스-J1.15%(게/국산)
# 38416                                             키토산올리고당분말(게)
# 38635                                                   콜라겐게이싱
# 38832                                                 짜파게티맛시즈닝
# 38909                                                비셰프굴소스(게)
# 39082                                             게엑기스분말(게:국산)
# 39095                                              게향(합성향료/게향S
# 39247                                     d-토코페롤(혼합형) 키토후레쉬(게)
# 39443                                  *스파게티면:듀럼휘트세몰리나(밀-이탈리아산
# 39994                                        붉은대게살10.12%(게:국산)
# 40432                                    게엑기스(게)1.3%산도조절제(탄산칼슘
# 40476                                               갑각류분해추출물(게
# 41193                                                크림스파게티베이스
# 41886                                      스파게티소스시즈닝믹스-WS{변성전분
# 42220                         게엑기스-디3.3%[게엑기스13.8{게97.5%(연근해산)
# 43042                               구운꽃게엑기스[튀긴꽃게효소분해액{꽃게(중국산)}
# 43538                                                게향(합성착향료)
# 43603                                                 명신씨엠이(게)
# 43996                                                    게(국산)
# 44055                                           게향0.52%(합성착향료)
# 44079                                           투게더클래식/원유(2배농축
# 44121                                        스파게티(이탈리아산)19.27%
# 44925                                                  부대찌게맛분말
# 45253  동결건조토마토스파게티77.1%[토마토스파게티소스-이77.8%{다이스드토마토20%(미국산/토마토65%
# 45506   토마토스파게티소스분말22.9%[토마토스파게티소스-이100%{다이스드토마토20%(미국산/토마토65%
# 45524                               게엑기스엔엠2.74%[게추출액(황게30%국산)]
# 46279                                                 스파게티소스분말
# 46367                             꽃게엑기스 4%[꽃게 추출액(국산) 고형분 37%]
# 46793                                                     게엑기스
# 46817                                      〮파스타면-스파게티(밀:이탈리아산)
# 46909                                             소금:커드무게의0.1%
# 47417                                            스파게티소스[양파(국산)
# 47508                                           혼합제제{게향(합성착향료)
# 47891                                        붉은대게다리살6.16%(국내산)
# 47903                                          녹차풍미액 *스프/홍게엑기스
# 48426                                            꽃게엑기스A[1.0%함유
# 48956                                     스파게티[듀럼세몰리나소맥분100%(밀
# 49214                                               복합해물엑기스(게)
# 49432                                                 붉은대게농축분말
# 49860                                                   홍게(국산)
# 50481                                      게살오므라이스(62.90%)-정제수
# 50956                        게엑기스2.74%[게엑기스54.2%(냉동게89.5%(국산)]
# 51344                                         스파게티(이탈리아산)18.5%
# 51854                                                  생강엑게스분말
# 51985                                                 게향(합성향료)
# 52441                                      게엑기스-디0.52%(게/연근해산)
# 52606                                      붉은대게농축페이스트(붉은대게:국산)
# 52961                                   붉은대게살[붉은대게살70%(영덕산)]5%
# 52987                                                  부대찌게향미유
# 53158                                               게엑기스(게:국산)
# 53421                                                토마토스파게티소스
# 53651                                                  게농축액(게)
# 53895                                                      게5%
# 53947                                           게향1.09%(합성착향료)
# 54174                                  게엑기스-DS1 3.12%{꽃게(국내산)}
# 54558                                       붉은대게다리살10.45%(국내산)
# 54713                                                     게엑기스
# 54968                                     게엑기스-디1.39%{게(연근해산)}
# 55625                                                게향(합성보존료)
# 55770                            꽃게엑기스A[0.14% 함유(꽃게0.9%상당;국산)]
# 55804                                 마르게리타다이스토마토25%(토마토69.98%
# 56542                                                  홍게맛살(어육
# 56781                                           게향0.45%(합성착향료)
# 56965                                                 게향(합성향료)
# 57227                         N-아세틸글루코사민분말(게)0.011%(글루코사민(NAG)
# 57446                                                      유화게
# 57800                                               게엑기스(게:국산)
# 57909                              크림스파게티베이스D{양송이엑기스분말(양송이:국산)
# 57982                                            게향0.71%(합성향료)
# 58018                        동결건조스파게티면44%[까펠리니(이탈리아산/세몰리나듀럼밀)]
# 58167                                               울진붉은대게8.2%
# 58254                         N-아세틸글루코사민분말(게)0.011%[글루코사민(NAG)
# 58315                               꽃게탕분말스프<생라면짬뽕맛분말{정제소금(국내산)
# 58558                                              복합해물농축액(게)]
# 58762                      정제수)\n〮토마토 스파게티소스-다이스토마토25%(미국산:토마토
# 58819                                        붉은대게다리살6.03%(국내산)
# 58915                                               홍게다리살2.64%
# 58940                                         게엑기스-J0.9%(게/국산)
# 59230                                   꽃게추출물분말{꽃게추출물(꽃게:국내산)}
# 59362                                      게엑기스-J 1.15%(게/국내산)
# 59720                                                    꽃게베이스
# 59758                                                멍게(국산)75%
# 59835                                              게농축액(게:국산)]
# 60182                                                   게(국내산)
# 60238                              트레하)*특정성분:스프 중 홍게 6.9%(생물기준
# 60560                                            게향0.5%(합성착향료)
# 60779                  일동락토바실루스스포로게네스(Lactobacillus sporogenes
# 60944                                               꽃게(국내산) 4%
# 61400                                                 합성착향료(게향
# 61428                                                 꽃게베이스(게)
# 61726                                               스파게티[이탈리아산
# 62055                                       가라게알파믹스[밀가루(밀:미국산)
# 62360                                                 크림스파게티소스
# 62485                                치자황색소*스파게티소스(130gx2개)-정제수
# 62809                                                       게)
# 62932                                          칠리토마토스파게티소스{정제수
# 63211                                                     국산/게
# 63444                                                     다시마게
# 63524                                                      유게놀
#
#                          전처리
# 206                꽃게씨즈닝분말
# 487                  붉은대게엑기스
# 556                   콘베리게이트
# 575                       게향
# 627                    붉은대게살
# 827                   가라아게배터
# 1070                  가라아게배터
# 1276         가라아게염지제호폴리인산나트륨
# 1594                   게랑드소금
# 1750                  가라아게배터
# 2196                      게향
# 2544                  꽃게엑기스A
# 2634                   어육추출액
# 2801                    스파게티
# 3295              향미증진제 해물함량
# 3377               게맛살조미후레이크
# 3538                     소스류
# 3816                   해물베이스
# 3819      크림스파게티베이스D양송이엑기스분말
# 3852                붉은대게농축분말
# 4423                 게 엑기스분말
# 4898                     꽃게
# 4922                    게라나올
# 5522                스파게티면밀가루
# 5850               생스파게티면밀가루
# 6032                   게엑기스J
# 6209                  대게페이스트
# 6248                   붉은대게살
# 6300             N아세틸글루코시민분말
# 6497                   붉은대게살
# 6529                    스파게티
# 6600                   게엑기스게
# 6630                    붉은대게
# 6736                    게엑기스
# 6760                크림스파게티분말
# 6960                 복합해물농축액
# 7059                     홍게살
# 7224               말토게닉아밀라아제
# 7519                       게
# 8042                 붉은대게다리살
# 8103              레드가라게믹스밀가루
# 8358                 꽃게탕면건더기
# 8454                      꽃게
# 8456                      게향
# 9143                스파게티면밀가루
# 9370      정제수 토마토스파게티소스골드정제수
# 9423         페스토스파게티야채건더기건마늘
# 9923                   스파게티면
# 10371            붉은대게농축액붉은대게
# 10527       시컴오일 스파게티치즈분말알파콘
# 10692          스파게티소스시즈닝믹스TS
# 11557                꽃게풍미베이스
# 11617    게다리살 호두컵샐러드올리브그린치커리
# 11963                  게엑기스게
# 12310                      게
# 12329                    NaN
# 12446                  게엑기스게
# 12467                   꽃게짬뽕
# 12558                     멍게
# 12566                 게농축액분말
# 13375                    굴소스
# 13451                     게향
# 13972   조개관자엑기스조개관자추출액참치뼈엑기스
# 14314          스파게티면듀럼휘트세몰리나
# 14833                     게향
# 14861               게라닐아세테이트
# 14893                    냉동게
# 14922                  키토후레쉬
# 15024                 게엑기스분말
# 15076         스파게티소스시즈닝믹스TSA
# 15156             가라아게배터믹스DS
# 15190                  꽃게농축액
# 16029              꽃게짬뽕해물건더기
# 16212                    게맛살
# 16922              말토게닉아밀라아제
# 17126                조개관자액기스
# 17325                 갑각류추출물
# 17351                 게엑기스분말
# 17453             후추가루해물함량해물
# 17840                  붉은대게살
# 17884                가라아게믹스므
# 17957                  꽃게풍미유
# 18057               순살치킨배터믹스
# 18097                붉은대게농축액
# 18131               스파게티소스분말
# 18458               갑각류분해추추물
# 18518               파스타면스파게티
# 18792                   게농축액
# 19268                  붉은대게살
# 19471                  키토후레쉬
# 20270                      게
# 20338                      게
# 20735                  꽃게농축액
# 20971                      게
# 21025                붉은대게자숙액
# 21029                    NaN
# 21278            칠리토마토스파게티소스
# 21863                  어육추출액
# 21906                  크랩엑기스
# 22623                 게란후레이크
# 23444                스파게티용믹스
# 23539               튀긴꽃게오일꽃게
# 23568        치자황색소 스파게티소스정제수
# 23620                    게맛살
# 23812                 게엑기스P게
# 23830                 게랑드천일염
# 23929                홍게엑기스분말
# 24188                  게엑기스게
# 24302                  붉은대게살
# 24367                   홍게맛살
# 24418                  꽃게엑기스
# 24461                  치킨엑게스
# 24648                 게엑기스디게
# 24740                  게 엑기스
# 25242                  꽃게추출물
# 25362                    게맛살
# 25751               유산균발효분말S
# 26542           가라아게염지제옥수수전분
# 26799                   게농축액
# 27146                   게엑기스
# 27385                  합성착향료
# 27393            마르게리타다이스토마토
# 27620                     게향
# 27777   게엑기스특정성분함량및원산지스프류중새우
# 27834                홍게엑기스분말
# 28246                 게랑드천일염
# 28628               구연산 해물함량
# 28659                      게
# 28823     꽃게탕액상스프탕면맛베이스꽃게엑기스
# 29573                   스파게티
# 29767            칠리토마토스파게티소스
# 29861                     게향
# 30330                 복합조미식품
# 30391                      게
# 30491            쓰리인원내츄럴믹스게향
# 30852                      게
# 31799                  붉은대게살
# 31856                   합성향료
# 32465       트레하 특정성분스프 중 홍게
# 32703                   키토산
# 33287                   대게내장
# 33524               조미게엑기스분말
# 34411                  붉은대게살
# 34771     정제염  스파게티면듀럼휘트세몰리나
# 34913                게추출농축액호
# 34927                게맛살소맥전분
# 35311                 게엑기스엔엠
# 35659                게추출농축액호
# 35738                  게엑기스게
# 36334                    키토산
# 36861                가라아게염지제
# 37302                 개농축액분말
# 37890                  붉은대게살
# 38073                  게엑기스J
# 38416              키토산올리고당분말
# 38635                 콜라겐게이싱
# 38832               짜파게티맛시즈닝
# 38909                 비셰프굴소스
# 39082                 게엑기스분말
# 39095                     게향
# 39247            d토코페롤 키토후레쉬
# 39443          스파게티면듀럼휘트세몰리나
# 39994                  붉은대게살
# 40432              게엑기스산도조절제
# 40476               갑각류분해추출물
# 41193              크림스파게티베이스
# 41886      스파게티소스시즈닝믹스WS변성전분
# 42220                  게엑기스디
# 43042                구운꽃게엑기스
# 43538                     게향
# 43603                  명신씨엠이
# 43996                      게
# 44055                     게향
# 44079               투게더클래식원유
# 44121                   스파게티
# 44925                부대찌게맛분말
# 45253            동결건조토마토스파게티
# 45506            토마토스파게티소스분말
# 45524                 게엑기스엔엠
# 46279               스파게티소스분말
# 46367            꽃게엑기스  고형분
# 46793                   게엑기스
# 46817               파스타면스파게티
# 46909                소금커드무게의
# 47417                 스파게티소스
# 47508                 혼합제제게향
# 47891                붉은대게다리살
# 47903          녹차풍미액 스프홍게엑기스
# 48426                 꽃게엑기스A
# 48956                   스파게티
# 49214                복합해물엑기스
# 49432               붉은대게농축분말
# 49860                     홍게
# 50481             게살오므라이스정제수
# 50956                   게엑기스
# 51344                   스파게티
# 51854                생강엑게스분말
# 51985                     게향
# 52441                  게엑기스디
# 52606             붉은대게농축페이스트
# 52961                  붉은대게살
# 52987                부대찌게향미유
# 53158                   게엑기스
# 53421              토마토스파게티소스
# 53651                   게농축액
# 53895                      게
# 53947                     게향
# 54174              게엑기스DS 꽃게
# 54558                붉은대게다리살
# 54713                   게엑기스
# 54968                 게엑기스디게
# 55625                     게향
# 55770                 꽃게엑기스A
# 55804            마르게리타다이스토마토
# 56542                   홍게맛살
# 56781                     게향
# 56965                     게향
# 57227            N아세틸글루코사민분말
# 57446                    유화게
# 57800                   게엑기스
# 57909     크림스파게티베이스D양송이엑기스분말
# 57982                     게향
# 58018              동결건조스파게티면
# 58167                 울진붉은대게
# 58254            N아세틸글루코사민분말
# 58315    꽃게탕분말스프생라면짬뽕맛분말정제소금
# 58558                복합해물농축액
# 58762  정제수\n토마토 스파게티소스다이스토마토
# 58819                붉은대게다리살
# 58915                  홍게다리살
# 58940                  게엑기스J
# 59230           꽃게추출물분말꽃게추출물
# 59362                 게엑기스J
# 59720                  꽃게베이스
# 59758                     멍게
# 59835                   게농축액
# 60182                      게
# 60238        트레하특정성분스프 중 홍게
# 60560                     게향
# 60779         일동락토바실루스스포로게네스
# 60944                    꽃게
# 61400                  합성착향료
# 61428                  꽃게베이스
# 61726                   스파게티
# 62055                가라게알파믹스
# 62360               크림스파게티소스
# 62485         치자황색소스파게티소스정제수
# 62809                      게
# 62932         칠리토마토스파게티소스정제수
# 63211                    국산게
# 63444                   다시마게
# 63524                    유게놀

# %% [markdown]
# # 2. (haccp의 원재료 데이터, 비선호음식)
# 1. (품목보고번호, 비선호음식)이 연결된 테이블 만들기
# 2. (품목보고번호, 원재료 string)

# %% [markdown]
# ### 2-1. (품목보고번호, 비선호음식)이 연결된 테이블 만들기

# %% [markdown]
# #### haccp

# %%
# 데이터 디렉토리 설정
HACCP = "HACCP.csv"
DISLIKED_TO_RAWMTR = "disliked_to_mtr.csv"

# %%
# haccp dataframe 열기
haccp_df = pd.read_csv(DATA_PATH / HACCP, encoding="utf-8")
print(f'{haccp_df.shape}')
haccp_df = haccp_df.reset_index().rename(columns={"index": "id"})
haccp_df = haccp_df.drop(columns=['item.barcode', 'item.allergy'])
haccp_df.head(5)
# Out:
# (15002, 5)
#    id    item.prdlstNm  \
# 0   0       설화눈꽃팝김부각스낵
# 1   1  설화눈꽃팝김부각스낵 아몬드맛
# 2   2         눈꽃팝김부각스낵
# 3   3           참군고구마칩
# 4   4            참군고구마
#
#                                                        item.rawmtrl  \
# 0      찹쌀,김,참깨,옥수수기름(옥배유),양파,무,대파,천일염,마늘,새우,멸치,다시마,건표고버섯,둥굴레,감초,정제수
# 1  찹쌀,김,참깨,옥수수기름(옥배유),아몬드,양파,무,천일염,대파,마늘,새우,멸치,다시마,건표고버섯,둥굴레,감초,정제수
# 2      찹쌀,김,참깨,옥수수기름(옥배유),양파,무,대파,천일염,마늘,새우,멸치,다시마,건표고버섯,둥굴레,감초,정제수
# 3                                                              군고구마
# 4                                                              군고구마
#
#   item.prdlstReportNo
# 0        201904962715
# 1        201904962712
# 2        201904962711
# 3        201903787252
# 4        201903787251

# %%
# rawmtrs 다른 행으로 분리
haccp_df['item.rawmtrl'] = haccp_df['item.rawmtrl'].str.split(',')
haccp_df_exploded = haccp_df.explode('item.rawmtrl')
haccp_df_exploded.head(5)
# Out:
#    id item.prdlstNm item.rawmtrl item.prdlstReportNo
# 0   0    설화눈꽃팝김부각스낵           찹쌀        201904962715
# 0   0    설화눈꽃팝김부각스낵            김        201904962715
# 0   0    설화눈꽃팝김부각스낵           참깨        201904962715
# 0   0    설화눈꽃팝김부각스낵   옥수수기름(옥배유)        201904962715
# 0   0    설화눈꽃팝김부각스낵           양파        201904962715

# %% [markdown]
# #### disliked

# %%
disliked_df = pd.read_csv(DATA_PATH / DISLIKED_TO_RAWMTR, encoding="utf-8")
#disliked_df = disliked_df.reset_index().rename(columns={"index": "id"})
disliked_df = disliked_df.drop(columns=["Unnamed: 0"])
print(f'{disliked_df.shape}')
disliked_df.head(5)
# Out:
# (165, 3)
#    id rawmtrs  disliked_id
# 0   0      분유            0
# 1   1      우유            0
# 2   2      유청            0
# 3   3      밀크            0
# 4   4      밀키            0

# %%
# rawmtrs 다른 행으로 분리
disliked_df['rawmtrs'] = disliked_df['rawmtrs'].str.split(', ')
disliked_df_exploded = disliked_df.explode('rawmtrs')
disliked_df_exploded.head(5)
# Out:
#    id rawmtrs  disliked_id
# 0   0      분유            0
# 1   1      우유            0
# 2   2      유청            0
# 3   3      밀크            0
# 4   4      밀키            0

# %% [markdown]
# ### merge

# %%
merged_df = pd.merge(haccp_df_exploded, disliked_df_exploded, how='cross')
print(f'{merged_df.shape}')
# Out:
# (40851360, 7)

# %%
def merge_function(row):
    try:
        return  row['rawmtrs'] in row['item.rawmtrl']
    except:
        return False

# %%
result = merged_df[merged_df.apply(merge_function, axis=1)]
print(f'{result.shape}')
result.head(5)
# Out:
# (58180, 7)
#       id_x    item.prdlstNm item.rawmtrl item.prdlstReportNo  id_y rawmtrs  \
# 2144     0       설화눈꽃팝김부각스낵        건표고버섯        201904962715   164      버섯
# 2184     0       설화눈꽃팝김부각스낵          둥굴레        201904962715    39       굴
# 4949     1  설화눈꽃팝김부각스낵 아몬드맛        건표고버섯        201904962712   164      버섯
# 4989     1  설화눈꽃팝김부각스낵 아몬드맛          둥굴레        201904962712    39       굴
# 7589     2         눈꽃팝김부각스낵        건표고버섯        201904962711   164      버섯
#
#       disliked_id
# 2144           19
# 2184           10
# 4949           19
# 4989           10
# 7589           19

# %%
result_nospace = result[result['rawmtrs']!='']
print(f'{result_nospace.shape}')
# Out:
# (58922, 7)

# %%
result_nospace = result_nospace.drop(columns=['id_x', 'id_y'])
result_nospace.head(10)
# Out:
#         item.prdlstNm item.rawmtrl item.prdlstReportNo  disliked rawmtrs
# 1666       설화눈꽃팝김부각스낵           새우        201904962715      새우/게      새우
# 2378       설화눈꽃팝김부각스낵        건표고버섯        201904962715        버섯      버섯
# 2438       설화눈꽃팝김부각스낵          둥굴레        201904962715   오징어/어패류       굴
# 3778  설화눈꽃팝김부각스낵 아몬드맛          아몬드        201904962712  잣/호두/아몬드     아몬드
# 4777  설화눈꽃팝김부각스낵 아몬드맛           새우        201904962712      새우/게      새우
# 5489  설화눈꽃팝김부각스낵 아몬드맛        건표고버섯        201904962712        버섯      버섯
# 5549  설화눈꽃팝김부각스낵 아몬드맛          둥굴레        201904962712   오징어/어패류       굴
# 7705         눈꽃팝김부각스낵           새우        201904962711      새우/게      새우
# 8417         눈꽃팝김부각스낵        건표고버섯        201904962711        버섯      버섯
# 8477         눈꽃팝김부각스낵          둥굴레        201904962711   오징어/어패류       굴

# %%
#result_nospace.to_csv(DATA_PATH / "product_to_rawmtr.csv")

# %% [markdown]
# #### 마지막 정제

# %%
PRODUCT_TO_RAWMTR = "product_to_rawmtr.csv"
product_to_rawmtr_df = pd.read_csv(DATA_PATH / PRODUCT_TO_RAWMTR, encoding="utf-8")
product_to_rawmtr_df = product_to_rawmtr_df.drop(columns=["Unnamed: 0"])
product_to_rawmtr_df.head(3)
# Out:
#   item.prdlstNm item.rawmtrl item.prdlstReportNo disliked rawmtrs
# 0    설화눈꽃팝김부각스낵           새우        201904962715     새우/게      새우
# 1    설화눈꽃팝김부각스낵        건표고버섯        201904962715       버섯      버섯
# 2    설화눈꽃팝김부각스낵          둥굴레        201904962715  오징어/어패류       굴

# %%
product_to_rawmtr_df = product_to_rawmtr_df.rename(columns={"item.prdlstReportNo": "prdlstReportNo"})
product_to_rawmtr_df.head(3)
# Out:
#   item.prdlstNm item.rawmtrl prdlstReportNo disliked rawmtrs
# 0    설화눈꽃팝김부각스낵           새우   201904962715     새우/게      새우
# 1    설화눈꽃팝김부각스낵        건표고버섯   201904962715       버섯      버섯
# 2    설화눈꽃팝김부각스낵          둥굴레   201904962715  오징어/어패류       굴

# %%
def search(pname, exclude):
   if exclude:
      filtered = product_to_rawmtr_df[product_to_rawmtr_df['item.rawmtrl'].str.contains(exclude)==False]
      filtered = filtered[filtered['rawmtrs'].str.contains(pname)==True]
      filtered = filtered[['item.rawmtrl', 'disliked', 'rawmtrs']]
      print(f'{filtered.shape}')
      display(filtered)
      return

   filtered = product_to_rawmtr_df[product_to_rawmtr_df['rawmtrs'].str.contains(pname)==True]
   filtered = filtered[['item.rawmtrl', 'disliked', 'rawmtrs']]
   print(f'{filtered.shape}')
   display(filtered)

# %%
search(pname="잣", exclude=None)
# Out:
# (55, 3)
#                  item.rawmtrl  disliked rawmtrs
# 23                          잣  잣/호두/아몬드       잣
# 29                          잣  잣/호두/아몬드       잣
# 367                         잣  잣/호두/아몬드       잣
# 375                         잣  잣/호두/아몬드       잣
# 3767                 유기농잣(국산)  잣/호두/아몬드       잣
# 4849                        잣  잣/호두/아몬드       잣
# 8477                  잣(국산)1%  잣/호두/아몬드       잣
# 9152                잣(국산)0.2%  잣/호두/아몬드       잣
# 23926                   잣(국산)  잣/호두/아몬드       잣
# 23936                   잣(국산)  잣/호두/아몬드       잣
# 24597                잣[국산]3%)  잣/호두/아몬드       잣
# 25389                잣15%(국산)  잣/호두/아몬드       잣
# 27294  잣(국산)\n연근정과:연근(국산) 80%  잣/호두/아몬드       잣
# 28833                      잣)  잣/호두/아몬드       잣
# 28872                      잣)  잣/호두/아몬드       잣
# 28879                      잣)  잣/호두/아몬드       잣
# 28887                      잣)  잣/호두/아몬드       잣
# 28901                   잣-국산)  잣/호두/아몬드       잣
# 28931        잣페이스트0.11%(잣100%  잣/호두/아몬드       잣
# 28940                      잣)  잣/호두/아몬드       잣
# 28953                      잣)  잣/호두/아몬드       잣
# 28966                      잣)  잣/호두/아몬드       잣
# 28977                      잣)  잣/호두/아몬드       잣
# 28986                      잣)  잣/호두/아몬드       잣
# 32743                   잣(국산)  잣/호두/아몬드       잣
# 32745                   잣(국산)  잣/호두/아몬드       잣
# 32801                   잣(국산)  잣/호두/아몬드       잣
# 34766         잣페이스트0.1%(88%이상  잣/호두/아몬드       잣
# 38230               잣0.5%(국산)  잣/호두/아몬드       잣
# 38529               잣0.3%(국산)  잣/호두/아몬드       잣
# 38662               잣0.3%(국산)  잣/호두/아몬드       잣
# 39124                       잣  잣/호두/아몬드       잣
# 39181                   잣(국산)  잣/호두/아몬드       잣
# 39189                       잣  잣/호두/아몬드       잣
# 39236                   잣(국산)  잣/호두/아몬드       잣
# 39298                       잣  잣/호두/아몬드       잣
# 39327               잣(국산)0.5%  잣/호두/아몬드       잣
# 40630                  잣0.03%  잣/호두/아몬드       잣
# 43572                 잣5%(국산)  잣/호두/아몬드       잣
# 45424                   잣(국산)  잣/호두/아몬드       잣
# 49597                   잣페이스트  잣/호두/아몬드       잣
# 49617                   잣페이스트  잣/호두/아몬드       잣
# 49633         잣페이스트0.1%(88%이상  잣/호두/아몬드       잣
# 50534                      잣]  잣/호두/아몬드       잣
# 50590                      잣)  잣/호두/아몬드       잣
# 50603                      잣]  잣/호두/아몬드       잣
# 50626                      잣]  잣/호두/아몬드       잣
# 50638                잣(국산)3%]  잣/호두/아몬드       잣
# 50664                      잣]  잣/호두/아몬드       잣
# 50752                      잣]  잣/호두/아몬드       잣
# 51104                       잣  잣/호두/아몬드       잣
# 51124              잣1.5%(중국산)  잣/호두/아몬드       잣
# 51141             잣1.35%(중국산)  잣/호두/아몬드       잣
# 56681                 잣3%(국산)  잣/호두/아몬드       잣
# 56684               잣향(합성착향료)  잣/호두/아몬드       잣

# %% [markdown]
# drop 명단
# 1. 둥굴레 (굴)
# 2. 버팔로윙마리네이션 (윙)
# 3. 윙믹스-F (윙)
# 4. 아카리돈산 (돈)

# %%
filtered = product_to_rawmtr_df[product_to_rawmtr_df['item.rawmtrl'].str.contains("둥굴레")==False]
filtered = filtered[filtered['item.rawmtrl'].str.contains("버팔로윙마리네이션")==False]
filtered = filtered[filtered['item.rawmtrl'].str.contains("윙믹스-F")==False]
filtered = filtered[filtered['item.rawmtrl'].str.contains("아카리돈산")==False]
print(f'{filtered.shape}')
filtered.head(3)
# Out:
#      item.prdlstNm item.rawmtrl prdlstReportNo  disliked rawmtrs
# 0       설화눈꽃팝김부각스낵           새우   201904962715      새우/게      새우
# 1       설화눈꽃팝김부각스낵        건표고버섯   201904962715        버섯      버섯
# 3  설화눈꽃팝김부각스낵 아몬드맛          아몬드   201904962712  잣/호두/아몬드     아몬드

# %%
# disliked.csv id 추가
DISLIKED = "disliked.csv"
disliked_df = pd.read_csv(DATA_PATH / DISLIKED, encoding="utf-8")
disliked_df = disliked_df.reset_index().rename(columns={"index":"id"})
disliked_df.to_csv(DATA_PATH / "disliked.csv", index=False)

# %%
# disliked_to_rawmtr disliked name -> index
disliked_to_rawmtr =  pd.read_csv(DATA_PATH / DISLIKED_TO_RAWMTR, encoding="utf-8")
disliked_to_rawmtr_merged = pd.merge(disliked_to_rawmtr, disliked_df, how="inner")
disliked_to_rawmtr_merged = disliked_to_rawmtr_merged.drop(columns=["disliked"])
#disliked_to_rawmtr_merged.head(4)

disliked_to_rawmtr_merged['rawmtrs'] = disliked_to_rawmtr_merged['rawmtrs'].str.split(',')
disliked_to_rawmtr_merged_exploded = disliked_to_rawmtr_merged.explode('rawmtrs')
disliked_to_rawmtr_merged_exploded = disliked_to_rawmtr_merged_exploded.rename(columns={"id":"disliked_id"})
disliked_to_rawmtr_merged_exploded = disliked_to_rawmtr_merged_exploded.reset_index(drop=True)
disliked_to_rawmtr_merged_exploded = disliked_to_rawmtr_merged_exploded.reset_index().rename(columns={"index":"id"})
disliked_to_rawmtr_merged_exploded.head(5)
#disliked_to_rawmtr_merged_exploded.to_csv(DATA_PATH / "disliked_to_mtr.csv")
# Out:
#   rawmtrs  id
# 0      분유   0
# 0      우유   0
# 0      유청   0
# 0      밀크   0
# 0      밀키   0

# %%
product_to_disliked = pd.merge(filtered, disliked_df, how="inner")
product_to_disliked = product_to_disliked.drop(columns=["item.prdlstNm", "item.rawmtrl", "disliked", "rawmtrs"])
product_to_disliked = product_to_disliked.rename(columns={"id":"disliked_id"})

# %%
product_to_disliked = product_to_disliked.reset_index().rename(columns={"index":"id"})
product_to_disliked.head(3)
# product_to_disliked.to_csv(DATA_PATH / "product_to_disliked.csv")
# Out:
#    id prdlstReportNo  disliked_id
# 0   0   201904962715           19
# 1   1   201904962712            5
# 2   2   201904962712           19

# %%
product_to_disliked.to_csv(DATA_PATH / "product_to_disliked.csv")

# %% [markdown]
# 데이터 수정

# %%
DATA_PATH = Path('../csv_files')
disliked_to_mtr = "disliked_to_mtr.csv"
product_to_disliked = "product_to_disliked.csv"

product_to_disliked_df = pd.read_csv(DATA_PATH / product_to_disliked, encoding="utf-8")
disliked_to_mtr_df = pd.read_csv(DATA_PATH / disliked_to_mtr, encoding="utf-8")

# %%
product_to_disliked_df.head(3)
# Out:
#    id prdlstReportNo  disliked_id
# 0   0   201904962715           19
# 1   1   201904962712            5
# 2   2   201904962712           19

# %%
disliked_to_mtr_df.head(3)
# Out:
#    id rawmtrs  disliked_id
# 0   0      분유            0
# 1   1      우유            0
# 2   2      유청            0

# %%
product_to_disliked_df = product_to_disliked_df.drop(columns=["Unnamed: 0"])
disliked_to_mtr_df = disliked_to_mtr_df.drop(columns=["Unnamed: 0"])

# %%
disliked_to_mtr_df['rawmtrs'] =  disliked_to_mtr_df['rawmtrs'].str.replace(" ", "")
disliked_to_mtr_df.head(3)
# Out:
#    id rawmtrs  disliked_id
# 0   0      분유            0
# 1   1      우유            0
# 2   2      유청            0

# %%
product_to_disliked_df.to_csv(DATA_PATH / product_to_disliked, encoding="utf-8", index=False)
disliked_to_mtr_df.to_csv(DATA_PATH / disliked_to_mtr, encoding="utf-8", index=False)
